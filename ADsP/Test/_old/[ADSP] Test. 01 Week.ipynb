# %% [markdown]
# ## 1 day. 데이터의 이해
#
#
#
# 1. 데이터는 암묵지와 형식지로 구분할 수 있다. 암묵지는 개인에게 경험적으로 축척되어 있지만 겉으로 드러나지 않은 지식을 의미한다. 이런 ( A )된 지식을 조직의 지식으로 ( B ) 하는 상호작용이 필요한데 A, B에 알맞은 내용은?
#
# A. internalization, Socialization
#
# B. internalization, Connection
#
# C. Personalization, Communication
#
# D. Personalization, Combination
#
#
#
# 2. DIKW 피라미드 중 다음 내용이 설명하는 것은? "A 마트의 상품이 B 마트의 상품보다 싸다"
#
# A. 정보
#
# B. 지성
#
# C. 지식
#
# D. 지혜
#
#
#
# 3. 다음 중 기업 기반 데이터베이스 활용 사례는?
#
# A. NEIS
#
# B. EDI
#
# C. EAI
#
# D. CALS

# %% [markdown]
# ## 2 day. 빅데이터의 이해
#
#
# 4. 서비스 사용자와 광고주를 연결하는 비즈니스는 사용자의 특성을 파악하여 정확한 고객군을 만드는 것이 중요하다. 이 목표를 위해 활용하기 시작한 것은 무엇인가? (주관식)
#
#
#
# 5. 신뢰할 수 없는 컴퓨터를 연결하여 클라우딩 기술로 대량의 데이터를 분산 처리하는 기술의 이름은? (주관식)
#
#
#
# 6. 빅데이터 활용 기본 테크닉 중에서 "새로운 환불 정책에 대한 고객의 평가는 어떤가"라는 질문에 가장 알맞은 분석 방법은 무엇인가?
#
# A. 기계 학습
#
# B. 감정분석
#
# C. 소셜 네트워크 분석
#
# D. 유형분석
#
#
#
# 7. 빅데이터가 발전하면서 여러 가지 문제점들이 나타나고 있는데 이를 위해 미국연방거래위원회가 제시한 권고사항이 아닌 건은?
#
# A. 개인정보 동의제를 책임제로 변경
#
# B. 소비자의 프라이버시 보호
#
# C. 공유 전보 선택 옵션 제공
#
# D. 수집 정보 내용 공개 및 접근권 부여

# %% [markdown]
# ## 3 day. 데이터 사이언스와 전략 인사이트
#
#
#
#
# 8. 가트너가 제시한 데이터 사이언스의 역량으로 적절하지 않은 것은?
#
# A. 커뮤니케이션
#
# B. 리더십
#
# C. 인문학 지식
#
# D. 협력
#
#
#
# 9. 일차원적 분석에 대한 설명을 가장 올바르지 않은 것은?
#
# A. 일차원적인 분석을 통해서도 해당 부서나 업무 영역에서 상당한 효과를 얻을 수 있다.
#
# B. 급변하는 환경에서는 그 효과가 미비할 수 있다.
#
# C. 차별화를 위해 전략적인 인사이트를 주는 기술기반 분석 단계로 발전해야 한다.
#
# D. 점점 분석 경험이 늘어나 작은 성공을 거두면 전략적 분석으로 발전할 수 있다.
#
#
#
# 10. 빅데이터 시대 가치 패러다임의 변화에 대한 설명으로 적절하지 않은 것은?
#
# A. 과거 PC와 워드프로세서, 이미징 기술의 발달로 문서를 디지털화하여 가치를 표준화함
#
# B. 압축기술의 발전으로 저장 비용이 감소하여 대용량 데이터 저장 기술의 발전.
#
# C. 다양한 디지털 정보를 필요한 사람에게 연결해서 효과적으로 정보를 제공.
#
# D. 방대한 정보를 하이퍼 연결을 통해 효과적으로 제공하고 관리할 수 있는 시대로 발전 예상.

# %% [markdown]
# ## 3.5 day. 최신 빅데이터 상식
#
#
#
#
# 11. 다음 중 SQL에 대한 설명으로 적절하지 않은 것은?
#
# A. 데이터 베이스에 접근할 수 있는 하위 언어이다.
#
# B. 테이블이 아닌 트랜젝션 단위로 연산을 수행한다.
#
# C. 영어 문장과 비슷한 구조이다.
#
# D. Stuctured Query Language의 약자이다.
#
#
#
# 12. Hadoop 플랫폼처럼 수많은 정보 속에서 의미 있는 내용을 찾기 위해 방식에 상관없이 데이터를 저장하는 시스템을 ( A )라고 한다. A에 들어갈 말로 적절한 것은?(주관식)
#
#
#
# 13. 다음 기술 중 성격이 다른 하나를 고르시오.
#
# A.  On-Line Transaction Processing
#
# B. Smart Factory
#
# C. Customer Relationship Management
#
# D.Enterprise Application Integration

# %% [markdown]
# ## 4 day. 데이터 분석 기획의 이해
#
#
# 14. 분석 과제는 목표 시점별로 당면한 과제를 빠르게 처리하는 ( A )와 지속적인 분석 분석 내재화를 위한 장기적인 ( B )으로 나눌 수 있다. A와 B에 적절한 단어를 선택하시오.
#
# A. 프로젝트 관리, 중장기 과제 관리
#
# B. 최적화 분석, 솔루션 분석
#
# C. 과제 단위 분석, 마스터플랜 단위 분석
#
# D. 대상 위주 분석, 방법 위주 분석
#
#
#
# 15. 빅데이터 분석 방법론 중 데이터 분석 단계에서 제작되는 산출물 중 향후 시스템 구현을 위한 사용자 인터페이스 또는 프로토타입으로 활용될 수 있는 것은?
#
# A. 텍스트 분석 보고서
#
# B. 데이터 탐색 보고서
#
# C. 데이터 시각화 보고서
#
# D. 모니터링 방안
#
#
#
# 16. 다음 중 CRISP-DM의 단계가 아닌 것을 고르시오.
#
# A. Datamining
#
# B. Business Understanding
#
# C. Evaluation
#
# D. Data Preparation

# %% [markdown]
# ## 5 day. 분석 과제 발굴
#
#
# 17. 분석 과제 발굴을 위한 방법 중 상향식 접근법은 분석 방법 4가지 유형중 ( A )에서 ( B )으로 발전하는 것을 의미한다. A와 B에 들어갈 내용으로 알맞은 것은?
#
# A. 발견, 통찰
#
# B. 솔루션, 발견
#
# C. 최적화, 솔루션
#
# D. 최적화, 통찰
#
#
#
# 18. 분석 과제의 문제 탐색을 위한 단계에서 비즈니스 모델 캔버스를 사용한다. 거시적 관점의 메가트렌드에서 경쟁자 관점에 대한 설명중 잘못된 것은?
#
# A. 현재 수행하는 있는 사업 영역 안에서 위협이 될 수 있는 상황에 대해 탐색한다.
#
# B. 현재 생산중인 제품 및 서비스를 온라인으로 제고하는 것에 대한 위험을 파악하는 것은 대체제 영역이다.
#
# C. 주요 경쟁자에 대한 동향을 파악하여 이를 고려한 분석 기회를 도출하는 것은 경쟁자 영역이다.
#
# D. 신규 전입자에 대한 동향을 파악하여 이를 고려한 분석 기회를 도출하는 것은 신규 전입자 영역이다.
#
#
#
# 19. 프로토타이핑의 내용으로 적절하지 않은 것은?
#
# A. 사용자의 요구사항이나 데이터를 정확히 정의하기 어려울 때 사용한다.
#
# B. 신속하게 해결책을 제시하여 문제를 좀 더 명확하게 인식할 수 있는 상향식 접근법이다.
#
# C. 데이터를 사용하는 목적은 수집 목적에 종속되므로 목적에 맞는 다양한 데이터를 수집한다.
#
# D. 가설의 샌성, 디자인에 대한 실험, 실제 환경 테스트, 테스트 결과에서 통찰 도출 과정으로 진행된다.

# %% [markdown]
# ## 6 day. 분석 마스터플랜
#
#
# 20. 기업 및 공공기관에서는 시스템의 중장기 로드맵을 정의하기 위해 ( A )를 수행한다. ( A )는 정보기술이나 정보시스템을 전략적으로 사용하기 위해서 조직 내, 외부 환경을 분석하여 기회나 문제점을 도출하고 사용자의 요구사항을 분석하여 시스템 구축 우선순위를 결정하는 등 중장기 마스터플랜을 결졍하는 절차이다. A에 알맞은 내용은? (주관식)
#
#
#
# 21. 일반적인 IT 프로젝트의 우선순위 평가를 위해 전략적 중요도, 실행 용의성 등 기업에서 고려하는 중요 가치 기준에 따라 다양한 관점에서 우선순위를 수립하여 평가한다. 다음 중 적절하지 않은 것은?
#
# A. 전략적 중요도 : 전략적 목표 및 본원적 업무에 직접적인 연관관계가 밀접한 정도
#
# B. 시급성 : 사용자의 요구사항, 업무능률 향상을 위해 시급히 수행되어야 하는지에 대한 정도
#
# C. 투자 용이성 : 분석 결과를 적용함으로 주정되는 실질적인 비용 절감, 매출과 수익 등 경제적 가치로 정도
#
# D. 기술 용이성 : 적용 기술의 안정성 검증 정도, H/W 유지보수 용이성 정도, 개발 기술 성숙도 및 신기술 적용성 정도
#
#
#
# 22. 포트폴리오 사분면 분석을 통해 과제 우선순위를 선정할 수 있다. 포트폴리오 사분면 중 3 사분면, 1 사분면, 2 사분면 순으로 의사결정을 하다면 어떤 요소를 평가 기준으로 한 것인지 알맞은 것을 고르시오.
#
# A. 이슈 미해결시 발생하는 위험 및 손실에 대한 정도를 고려하여 판단한다.
#
# B. 전략적 가치를 현재에 둘지, 미래에 둘 지를 고려하고 분석 과제의 목표가치를 함께 고려하여 판단한다.
#
# C. 현시점에서 과제를 추진하는 것이 비용 측면에서 쉬운 것인지 어려운 것인지 판단한다.
#
# D. 분석 결과를 통해 얻게 되는 비즈니스 효과를 고려하여 판단한다.
#
#
#
# 23. 기업의 데이터 분석 도입 수준을 파악하기 위하 진단 방법 중 분석 기법 영역의 질문으로 어울리지 않는 것은?
#
# A. 분석기법 정기적 개선 여부
#
# B. 비구조적 데이터의 관리 여부
#
# C. 분석기법 라이브러리 활용 여부
#
# D. 업무별 적합한 분석 기법 사용 여부
#
#
#
# 24. (A)는 소프트웨어 개발 및 전산 장비 운영 업체들의 능력 및 조직의 성숙도를 평가하기 위한 모델이다 ( A )는 무엇인가? (주관식)
#
#
#
# 25. 데이터 거버넌스의 체계 수립 중 데이터 표준 용어 설정, 명명 규칙 수립, 메타 데이터 구축, 데이터 사전 구축 등의 업무를 하는 단계는?
#
# A. 데이터 표준화
#
# B. 데이터 관리 체계
#
# C. 데이터 저장소 관리
#
# D. 표준화 활동
#
#
#
# 26. 분석 과제를 관리하는 프로세스는 분석 과제의 기획 및 운영을 체계적으로 관리하기 위해 진행된다. 분석 과제 관리 프로세스는 분석 아이디어를 발굴하고 이를 과제화 하여 과제 풀로 관리하면서 분석 프로젝트를 선정하는 ( A ) 단계와 분석을 수행할 팀을 구성하여 분석을 실행하고 지속적인 모니터링을 하는 ( B ) 단계로 나눌 수 있다. A와 B에 알맞은 내용은? (주관식)

# %% [markdown]
# ## 7 day. 데이터 분석기법의 이해
#
#
# 27. 운영 시스템에서 가져온 데이터를 임시 저장하는 영역의 이름은? (주관식)
#
#
#
# 28. 탐색적 자료 분석의 주제로 적당하지 않은 것은?
#
# A. 저항성의 강조
#
# B. 잔차 계산
#
# C. 그래프를 통한 현시성
#
# D. 자료 변수의 일반화

# %% [markdown]
# ----

# %% [markdown]
# 1. A    2.C    3.C    4. 사용자 로그 정보    5. 맵리듀스    6. B    7. A    8. C    9. C    10.B
#
# 11. B    12. 데이터 레이크    13. B    14. C    15. C    16. A    17. A    18. A    19. C    20. 정보전략계획, ISP
#
# 21. C    22. B    23.B    24. 능력 성숙도 통합 모델, CMMI    25. A    26. 과제 발굴, 과제 수행   27. 스테이징 영역   28. D
