# %% [markdown]
# ----

# %% [markdown]
# ## 제5장. 정형데이터 마이닝

# %% [markdown]
# ### 1. 데이터마이닝 개요
#
# 1. **데이터마이닝**
#     정의 : 대용량 데이터에서 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿을 파악하거나 예측하여 의사결정에 활용하는 방법
#     - 통계분석과 데이터마이닝의 차이
#         1. 통계분석 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿에 따른 분석이나 검증
#         1. 데이터 마이닝 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿를 이용해 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿를 추출
#     <br><br>
#     - 데이터마이닝 활용 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     <br><br>
#     - 데이터마이닝 방법론 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ 등
#     <br><br>
#
# 1. **데이터마이닝 학습법**
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿) : ＿＿＿＿＿＿변수가 존재, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     <br><br>
#     2. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿) : ＿＿＿＿＿＿변수가 없이 설명을 위한분석, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     <br><br>
#
# 1. **데이터마이닝 추진단계**
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ : 명확한 ＿＿＿＿ 설정
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ : 다양한 ＿＿＿＿＿＿＿＿를 준비 및 정제(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ : 목적변수를 정의, 모델링을 위한 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ : 기법을 ＿＿＿＿＿＿＿ 정보 추출
#     1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ : 결과를 ＿＿＿＿＿＿＿ 하고 업무에 적용, ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)등의 기대효과 전파
#     <br><br>
#
# 1. **데이터 분할**
#     1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : ＿＿＿＿＿＿＿%의 데이터를 훈련용으로 활용
#     1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : ＿＿＿＿＿＿＿%의 데이터를 과대/과소 추정의 판정 목적으로 사용
#     1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : ＿＿＿＿＿＿＿%의 데이터를 테스트데이터나 과거 데이터를 활용하여 성능평가에 활용
#     <br><br>
#
# 1. **모델의 성능 평가**
#     은행의 대출 문제로 연이율 20%로 가정, 100만원을 100명에게 대출한다고 가정
#     ![img](img/ROI.png)
#
#     1. 기대수익
#         1. 기대수익 = (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) - (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) = ＿＿＿＿＿＿＿만원
#         1. 기대수익 = (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) - (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) = ＿＿＿＿＿＿＿만원
#         <br><br>
#     1. 기대손실비용
#         1. 기대손실비용  = (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) + (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) = ＿＿＿＿＿＿＿만원
#         1. 기대손실비용  = (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) - (＿＿＿＿＿＿＿명 * ＿＿＿＿＿＿＿만원) = ＿＿＿＿＿＿＿만원
#         <br><br>
#     1. 결과
#         기대수익과 기대손실비용으로 봤을 때 ＿＿＿＿＿＿＿ 모형이 우수함

# %% [markdown]
# ### 2. 의사결정분석 나무
#
# 1. **분류분석 vs 예측분석**
#     1. 공통점 : 레코드의 ＿＿＿＿＿＿＿을 미리 알아 맞히는 점
#     1. 차이점
#         - 분류 : ＿＿＿＿＿＿＿ 속성의 값을 예측
#         - 예측 : ＿＿＿＿＿＿＿ 속성의 값을 예측
#     1. 분류의 예 : 학생들의 국어, 영어, 수학 점수를 예측, 카드회사에서 회원들의 가입정보를 통해 1년 후 신용등급을 예측
#     1. 분류기법
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿), ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿), C5.0
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿), ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)
#         1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)
#         1. 규칙기반 분류와 사례추론
#     <br><br>
#
#
# 1. **의사결정나무 특징**
#     - 분류함수를 의사결정 규칙으로 이뤄진 나무 모양으로 그리는 방법
#     - 의사결정 문제를 시각화하여 ＿＿＿＿＿＿＿과 ＿＿＿＿＿＿＿를 한 눈에 볼 수 있음
#     - ＿＿＿＿＿＿＿가 직접 나타나게 돼어 분석이 간편함
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿가 좋음
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿에서도 빠르게 만들 수 있음
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿에 대해서도 민감함 없이 분류
#     - ＿＿＿＿＿＿＿이 높은 다른 불필요한 변수에 큰 영향을 받지 않음
#     <br><br>
#
# 1. **의사결정나무 활용**
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : 비슷한 특성을 갖는 그룹으로 분할
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : 범주를 몇 개의 등급으로 나눔
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : 규칙을 찾고, 미래의 사건을 예상
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) 및 ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿) : 목표변수에 큰 영향을 미치는 변수를 고름
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿) : 여러개의 예측 변수들을 결합해 목표 변수 파악
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿) : 범주형 변수를 소수의 몇 개로 병합, 또는 연속형 변수를 몇 개의 등급으로 이산화
#     <br><br>
#
# 1. **의사결정나무 분석**
#     - 분석 단계 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ -> ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ -> ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ -> ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     - 나무의 가지치기 : 과적합, 과소적합을 예방하기 위해 마디의 자료가 일정수 이하일 경우 가지치기를 정지
#     - 분순도에 따른 분할 측도 : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#     <br><br>
#
# 1. **의사결정나무 분석의 종류**
#     1. ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#         - 목적변수가 범주형인 경우 ＿＿＿＿＿＿＿＿＿, 연속형인 경우 ＿＿＿＿＿＿＿＿＿을 이용해 ＿＿＿＿＿＿＿＿＿를 사용
#         - 개별 입력변수 뿐만 아니라 입력변수들의 선형결합등 중 최적의 분리를 찾을 수있다.
#         <br><br>
#     1. ＿＿＿＿＿＿＿＿＿와 ＿＿＿＿＿＿＿＿＿
#         - 다지분리가 가능, 범부형 변수의 범주 수만큼 분리 가능
#         - 불순도의 측도로 ＿＿＿＿＿＿＿＿＿ 지수 사용
#         <br><br>
#     1. ＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#         - 가지치기를 하지 않고 적당한 크기에서 나무모형을 성장을 중지
#         - 입력변수가 반드시 ＿＿＿＿＿＿＿＿＿ 변수이어야 함
#         - 불순도 측도로 ＿＿＿＿＿＿＿＿＿ 통계량 사용
#         <br><br>

# %% [markdown]
# ### 3. 앙상블 기법
#
# 1. **앙상블 기법**
#     - 주어진 자료들로부터 여러 개의 ＿＿＿＿＿＿＿＿＿들을 만든후 조합하여 하나의 ＿＿＿＿＿＿＿＿＿을 만드는 기업
#     - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿), classifier Convination 등
#     - 학습방법의 ＿＿＿＿＿＿＿＿＿을 해결하기 위해 고안
#     - 가장 불안전한 기법은 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿, 가장 안전한 기법은 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿
#
#     - 종류 :
#         1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#             - 여러 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿을 생성하고 예측모형 결과를 결과를 결합
#             - 훈련자료를 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿으로 생각하고 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿을 구한 것과 같음
#             - ＿＿＿＿＿을 줄이고, ＿＿＿＿＿＿을 향상 시킬 수 있음
#             <br><br>
#         1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#             - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿ 모형들을 결합하여 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿을 만드는 방법
#             - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿를 빨리 쉽게 줄일 수 있고, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿의 향상으로 ＿＿＿＿＿＿＿＿＿＿＿＿＿에 비해 뛰어난 예측력을 보임
#             <br><br>
#         1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#             - 의사결정나무의 특징인 분산이 크다는 점을 고려, ＿＿＿＿＿과 ＿＿＿＿＿＿＿ 보다 더 많은 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿을 주어 약한 학습기를 생성후 선형결합하여 ＿＿＿＿＿＿＿＿＿＿＿＿＿＿를 만드는 방법
#             - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿이나 해석이 어렵다는 단점, ＿＿＿＿＿＿＿＿＿＿＿＿＿＿이 매우 높은 장점
#             - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿가 많은 경우 더 좋은 예측력을 보임
#         1. ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#             - 동일한 타입의 모델을 조합하는 ＿＿＿＿, ＿＿＿＿과는 달리 다양한 학습 모델을 통해 구성
#             <br><br>
#
# 1. **오분류표**
# ![img](https://www.dataschool.io/content/images/2015/01/confusion_matrix2.png)
#
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : (TP+TN)/Total, 올바르게 검출 (실제 악성/정상을 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : (FP+FN)/Total, 잘못되게 검출 (잘못된 악성/정상 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : TP/Predicted YES, 참으로 분류한 것중 올바른 참의 비율 (악성으로 예측한 것 중 실제 악성 샘플의 비율)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : TP/Actual YES, 실제 참을 참으로 분류 (실제 악성 중에서 악성으로 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : FP/Actual NO, 실제 거짓을 거짓으로 분류 (실제 정상 중에서 악성으로 예측 )
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : TP/Actual YES, 예측과 실제 모두 참 (실제 악성 중에서 악성으로 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : TN/Actual NO, 예측과 실제 모두 거짓 (실제 정상 중에서 정상으로 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : FP/Actual NO, 실제 거짓인데 참으로 분류 (실제 정상을 악성으로 예측)
#     1. **[＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿]** : FN/Acutual YES, 실제 참인데 거짓으로 검출 (실제 악성을 정상으로 예측)
#
#
# 1. **ROC**
#     - ＿＿＿＿＿＿＿＿＿와 ＿＿＿＿＿＿＿＿＿를 활용하여 모형을 평가
#     - ＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿＿)
#         - ＿＿＿＿＿＿＿＿＿ = (AR+1)/2
#         - 90%이상 excellecnt, 80% 이상 good, 70% 이상 Fair

# %% [markdown]
# ### 4. 인공신경망 분석
#
# 1. **인공신경망 연구**
#     - 1943년 ＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿)과 ＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿) : 인간의 뇌를 수많은 신경세포가 연결된 하나의 ＿＿＿＿＿＿＿＿＿ ＿＿＿＿＿＿＿＿＿ 모형으로 간주, 신경세포의 신호처리 과정을 모형화 하여 단순 패턴분류 모형으로 개발
#     - 햅(Hebb) : 신경세포(뉴런) 사이의 ＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿)를 조정하여 학습규칙을 개발
#     - 로젠블럿(Rosenblatt) : ＿＿＿＿＿＿＿(＿＿＿＿＿＿＿)이라는 인공세포 개발, 비선형의 한계점 발생(＿＿＿＿＿＿＿)문제
#     - 홈필드(Hopfild), 러멜하트(Rumelhart), 맥클린드(McClelland) : ＿＿＿＿＿＿＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)을 활용하여 ＿＿＿＿＿＿＿을 극복한 ＿＿＿＿＿＿＿ 퍼셉트론으로 새로운 인공신경망 모형 등장
#     <br><br>
#
# 1. **뉴런(＿＿＿＿＿＿＿)**
#     - 아주 단순하지만 복잡하게 연결된 프로세스로 이루어져 있음
#     - ＿＿＿＿＿＿＿가 있는 ＿＿＿＿＿＿＿로 연결됨
#     - 여러개의 ＿＿＿＿＿＿＿를 받아 하나의 ＿＿＿＿＿＿＿를 생성
#     - ＿＿＿＿＿＿＿ 즉, ＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿＿＿)을 사용
#         - 입력신호의 ＿＿＿＿＿＿＿의 합을 계산하여 ＿＿＿＿＿＿＿과 비교
#         - ＿＿＿＿＿＿＿의 합이 ＿＿＿＿＿＿＿보다 작으면 뉴런의 출력은 ＿＿＿＿, 같거나 크면 ＿＿＿＿을 출력
#     <br><br>
#
# 1. **신경망모형 구축시 고려사항**
#     1. 입력변수
#         - ＿＿＿＿형 변수 : ＿＿＿＿가 일정수준 이상이고 빈도가 일정할 때
#             - 가변수화하여 적용(성별[남여], 남성[1,0], 여성[0,1])
#             <br><br>
#         - ＿＿＿＿형 변수 : 범위가 변수들간에 큰 차이가 없을 때
#             - 평균을 중심으로 ＿＿＿＿가 대칭이 아니면 비효율적
#             - ＿＿＿＿ 또는 ＿＿＿＿를 통해 활용하는 것이 적절
#     <br><br>
#
#     1. 가중치 초기값
#         - ＿＿＿＿＿＿＿＿＿＿＿＿＿＿의 경우, 초기값에 따라 결과가 크게 달라질 수 있으므로 중요
#         - 가중치가 0이면 ＿＿＿＿＿＿＿ 함수에서는 ＿＿＿＿＿＿＿이 되고 신경망 모형은 ＿＿＿＿＿＿＿모형이 됨.
#         - 초기값은 0 근처의 랜덤값으로 선정
#         - 초기에는 ＿＿＿＿＿＿＿모형에서 ＿＿＿＿＿＿＿가 증가하면서 ＿＿＿＿＿＿＿으로 변경 됨
#     <br><br>
#
#     1. 신경망 모형의 ＿＿＿＿함수는 비볼록하무이고, 여러 개의 국소 ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿)를 가짐
#         - 랜덤하게 선택된 여러개의 초기값에 대한 신경말을 적합한 후 얻은 해들을 비교하여 가장 ＿＿＿＿가 적은 것을 선택
#         - 최종 예측값을 얻거나 ＿＿＿＿(또는 ＿＿＿＿)을 구하여 최종 예측값으로 선정
#         - 훈련자료에 대해서 ＿＿＿＿(＿＿＿＿)을 적용하여 최종 예측값을 선정
#          <br><br>
#
#     1. 학습률
#         - 처음에는 큰 값으로 정하고 반복이 진행될 수록 ＿＿＿＿에 가까워 짐
#        <br><br>
#
#     1. ＿＿＿＿(＿＿＿＿＿＿＿＿), ＿＿＿＿노드(＿＿＿＿＿＿＿＿)의 수
#         - 많으면 가중치가 많아져 ＿＿＿＿＿＿＿＿문제 발생
#         - 적으면 ＿＿＿＿＿＿＿＿문제 발생
#         - 하나인 신경망은 범용근사자(Universal Approximator)이므로 가급적이면 하나로 선정
#         - 노드는 적절히 큰 값으로 설정하고 ＿＿＿＿를 감소하면서 모수에 대한 ＿＿＿＿를 적용
#     <br><br>
#
# 1. **로지스틱 회귀분석**
#     - ＿＿＿＿＿＿＿＿가 ＿＿＿＿＿형인 경우에 적용하는 회귀분석모형
#     - 새로운 ＿＿＿＿변수가 주어질 때 ＿＿＿＿변수의 각 범주에 속할 확률이 얼마인지 추정, 추정 확률을 기준으로 분류하는 목적으로 활용
#     - 모형의 적합을 통해 추정될 확률을 ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿)이라고 함
#     - ＿＿＿＿＿＿＿＿함수를 활용하여 로짓분석 실행
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿변수 ~ ＿＿＿＿변수1 + ＿＿＿＿변수2 + ... , family=binomial, data=데이터셋)
#     - 결과 추정값이 5.14이면, 독립변수의 단위가 증가함에 따라 종속변수가 0에서 1로 바뀔 ＿＿＿＿(＿＿＿＿)가 exp(5.140) = 170배 증가한다는 의미.

# %% [markdown]
# ### 5. 군집분석
#
# 1. **군집분석**
#     - 각 객체의 ＿＿＿＿＿＿＿＿을 측정하여 ＿＿＿＿＿＿＿＿이 높은 대상집단을 ＿＿＿＿
#     - 군집에 속한 객체들의 ＿＿＿＿＿＿＿＿과 서로 다른 군집에 속한 객체간의 ＿＿＿＿＿＿＿을 규명하는 분석 방법
#     - 특성에 따라 여러개의 ＿＿＿＿＿＿＿인 집단으로 나눔
#     - 군집의 ＿＿＿＿＿＿＿나 ＿＿＿＿＿＿＿에 대한 가정없이 ＿＿＿＿＿＿＿를 기준으로 군집화 유도
#     <br><br>
#
#
# 1. **군집분석 특징**
#     - ＿＿＿＿＿＿＿＿(＿＿＿＿＿＿＿＿＿＿＿＿)에 해당하며 ＿＿＿＿＿＿＿＿의 정의 없이 학습 가능
#     - 분석 목적에 따라 적절한 군집으로 정의 가능
#     - 요약분석과의 차이 : ＿＿＿＿ 변수를 묶는 것이 아닌 ＿＿＿＿를 묶어줌
#     - 판별변석과의 차이 : 판별분석은 사전에 집단이 나누어져 있어야 하지만, 군집분석은 ＿＿＿＿이 업는 상태에서 구분
#     <br><br>
#
# 1. **군집분석 거리 측정**
#
# 1. **계층적 군집 분석**
#
# 1. **비계층적 군집 분석**
#
# 1. **혼합분포 군집**
#
# 1. **SOM**

# %% [markdown]
# ### 6. 연관분석
#
#
# 1. **연관성 분석**
#
# 1. **연관성 규칙 개념**
#
# 1. **연관성 분석의 측도**
#
# 1. **연관분석 특징**
#
# 1. **평가기준 적용시 주의점**
#
# 1. **Apriori 가장 많이 사용하는 알고리즘**

# %% [markdown]
# ----
