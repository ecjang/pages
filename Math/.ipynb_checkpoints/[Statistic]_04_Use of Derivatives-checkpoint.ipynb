# %% [markdown]
# ##### 미적분과 통계기본

# %% [markdown]
# # 04. 도함수의 활용

# %% [markdown]
# ----

# %% [markdown]
# ### 04_1. 접선의 방정식

# %% [markdown]
# ##### 곡선 위의 점에서의 접선의 방정식
#
# 함수 $f(x)$가 미분가능할 때, 곡선 $y=f(x)$ 위의 점 $P(a, f(a))$에서의 접선의 기울기는 $x=a$에서의 미분계수 $f'(a)$와 같다.
# - **점 $P(a,f(a))$에서의 접선의 방정식 : $y-f(a)=f'(a)(x-a)$** <br><br>
# - **점 $P(a,f(a))$과 수직인 방정식 : $y-f(a)=-\frac{1}{f'(a)}(x-a) \text{ (단, f'(a)≠0)} $**
#
# #####  예 : 곡선 $y=x^3+x^2$ 위의 점 $P(1,2)$ 에서의 접선의 방정식
# $y'=3x^2+2x$이므로 기울기는 $y'_{x=1}=3+2=5$이므로 접선의 방정식은 아래와 같다.
# - 접선의 방정식: $ y-2=5(x-1) \,=\, y=5x-3 $

# %%
import matplotlib.pyplot as plt; import numpy as np

# %%
x = np.arange(-2,3, 0.01)
plt.plot(x,x**3 + x**2, label="$f(x)$")
plt.plot(x, 5*x-3, label="$y=5x-3$")
plt.plot(1,2,'o')
plt.grid()
plt.legend()
plt.annotate('P(1,2)',xy=(1,2), xytext=(0.2,5), fontsize=20 )
plt.show()

# %% [markdown]
# ##### 기울기가 주어진 접선의 방정식
#
# 함수 $f(x)$가 미분가능할 때, 기울기가 $m$이고 곡선 $y=f(x)$에 접하는 **직선의 방정식**은 다음과 같은 순서로 구한다.
# 1. 접점을 $(t, f(t))$로 놓는다.
# 1. $t$에 대한 방정식 $f'(t)=m$을 만족시키는 실수 $t$의 값을 구한다.
# 1. 접선의 방정식 $y=f(t)=f'(t)(x-t)$를 구한다.
#
# ##### 예: 곡선 $y=x^3$에 접하고 기울기가 3인 직선의 방정식
# - 접점을 $(t,t^3)$으로 놓으면 $y'=3x^2$이므로 $3t^2=3$ 이므로 $t=±1$이다.
# - 점 $P(-1,-1)$에서의 접선의 방정식은 $y+1=3(x+1)$에서 $y=3x+2$ 이다.
# - 점 $Q(1,1)$에서의 접선의 방정식은 $y-1=3(x-1)$에서 $y=3-2$이다.

# %%
plt.plot(x,x**3, label="$y=x^3$")
plt.plot(x,3*x+2, label="$y=3x+2$")
plt.plot(x,3*x-2, label="$y=3x-2$")
plt.plot(-1,-1,'o'); plt.plot(1,1,'o')
plt.annotate('P(-1,-1)', xy=(-1,-1), xytext=(-1.5,2), fontsize=20)
plt.annotate('Q(1,1)', xy=(1,1), xytext=(1,-2), fontsize=20)
plt.grid();plt.legend();plt.show()

# %% [markdown]
# ##### 곡선 밖의 한점에서  곡선에 그은 접선의 방정식
#
# 함수 $f(x)$가 미분가능할 때, 곡선 $y=f(x)$ 밖의 한 점 $(a,b)$에서 곡선 $y=f(x)$에 그은 접선의 방정식은 다음과 같은 순서로 구한다.
#
# 1. 접점을 $(t,f(t))$로 놓는다.
# 1. 점 $(t,f(t))$에서 접선의 방정식 $y-f(t)=f'(t)(x-t) ...㉠ $을 구한다.
# 1. 점 $(a,b)$는 접선 위의 점이므로 $x=a, y=b$를 ㉠에 대입한다.
# 1. $t$에 대한 방정식 $b-f(t)=f'(t)(a-t)$에서 실수값 $t$를 구한다.
# 1. 접선의 방정식 $y-f(t)=f'(t)(x-t)$를 구한다.
#
# ##### 예: 원점에서 곡선 $y=x^2+1$에 그은 접선의 방정식
# - 접점을 $(t,t^2+1)$로 놓으면 $y'=2x$이므로 접선의 방정식은 $y-(t^2+1)=2t(x-t)$이므로 접선의 방정식은 $y-(t^2+1)=2t(x-t)$이다.
# - 접선은 원점을 지나므로 $-(t^2+1)=2t(-t)$에서 $t^2=1$ 이므로 $t=±1$ 이다.
# - $y-2=-2(x-1)$ 에서 $y=-2x$
# - $y-2=2(x-1)$ 에서 $y=2x$

# %%
x = np.arange(-2,2, 0.01)
plt.plot(x,x**2+1, label="$y=x^2+1$")
plt.plot(x, -2*x, label="$y=-2x$")
plt.plot(x, 2*x, label="$y=2x$")
# plt.plot(1,2,'o')
# 

# plt.annotate('P(1,2)',xy=(1,2), xytext=(0.2,5), fontsize=20 )
plt.grid(); plt.legend(); plt.show()

# %% [markdown]
# ##### 두 곡선에 접하는 접선의 방정식 (접점이 같을 경우)
#
# 두 곡선 $y=f(x), y=g(x)$가 한 점 $P$에서 만나므로 점 $P$의 x좌표를 $t$라고 하면 $x=t$에서의 함숫값은 서로 같다.<br>
# 또한, **점 $P$에서의 접선은 같은 직선이므로 $x=t$에서의 미분계수는 값다.** 즉 다음 등식이 성립한다.
#
# $$ f(t)=g(t), \quad f'(t)=g'(t) $$

# %%
x = np.arange(-5, 5, 0.01)
plt.plot(x,(x-1)**2, label="$f(x)$")
plt.plot(x,-(x-1)**2, label="$g(x)$")
plt.plot(x, 1*x-1, label="$y=x$")
plt.plot(1, 0 ,'o')
plt.annotate('P(1 ,0)',xy=(1,0), xytext=(0,1), fontsize=20 )
plt.xlim(-5,5); plt.ylim(-5,5)
plt.grid(); plt.legend(); plt.show()

# %% [markdown]
# ##### 두 곡선에 접하는 접선의 방정식 (접점이 다를 경우)
#
# 두 곡선 $y=f(x), y=g(x)$의 접점을 각각 $P(\alpha, f(\alpha)), Q(\beta, g(\beta))$로 놓으면 두 점 $P,Q$에서의 접선은 같은 직선이다.<br>
# 점 $P$에서의 접선은 $y=f'(\alpha)(x-\alpha)+f(\alpha)$이고, 점 $Q$에서의 접선은 $y=g'(\beta)(x-\beta)+g(\beta)$이므로 다음과 같은 등식이 성립한다.
#
# $$ f'(\alpha)=g'(\beta), \quad -\alpha f'(\alpha)+f(\alpha) = -\beta g'(\beta)+g(\beta) $$

# %%
x = np.arange(-5,5,0.01)
plt.plot(x, (x-1)**2+1, label="$f(x)=(x-1)^2+1$")
plt.plot(x, -(x+1)**2-1, label="$g(x)=-(x+1)^2-1$")
plt.plot(x, x, label="$y=x$")
plt.plot(1,1,'o'); plt.plot(-1,-1,'o')
plt.annotate('P(1,f(1))', xy=(1,1), xytext=(0,3), fontsize=20)
plt.annotate('Q(1,f(1))', xy=(-1,-1), xytext=(-3,-0.5), fontsize=20)
plt.xlim(-5,5);plt.ylim(-5,5);plt.grid();plt.legend(loc='lower right');plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### 04_2. 함수의 증가와 감소

# %% [markdown]
# ##### 1. 함수의 증가와 감소
#
# 함수 $f(x)$가 있고 어떤 구간 임의의 두 수 $x_1, x_2$를 가정한다.
# 1. **증가한다** : $x_1 < x_2$일 때, $f(x_1) < f(x_2)$이면 해당 구간에서 증가한다.
# 1. **감소한다** : $x_1 < x_2$일 때, $f(x_1) > f(x_2)$이면 해당 구간에서 감소한다.
#
# ##### 1-1. 증가 감소 예
# 함수 $f(x)=x^2$에 대하여 $0<x_1<x_2$이면 $f(x_2)-f(x_1)=(x_2)^2-(x_1)^2 = (x_2-x_1)(x_2+x_1) > 0$ 이므로 $f(x_1)<f(x_2)$이다. 따라서 함수 $f(x)=x^2$는 구간 $(0, \infty)$에서 증가한다.

# %%
x = np.arange(-5,5,0.01)
plt.plot(x, x**2, label="$f(x)=x^2$")
plt.plot(1,1,'o'); plt.plot(-1,1,'o')
plt.annotate('$x_2(1,f(1))$', xy=(1,1), xytext=(0.5,0.5), fontsize=20)
plt.annotate('$x_1(-1,f(-1))$', xy=(-1,1), xytext=(-1,1.2), fontsize=20)
plt.xlim(-2,2);plt.ylim(0,2);plt.grid();plt.legend(loc='lower right');plt.show()

# %% [markdown]
# ##### 2. 함수의 증가상태와 감소상태
#
# 함수 $f(x)$가 충분히 작은 양수 $h$에 대하여 $f(a-h) < f(a) < f(a+h)$이면 함수$f(x)$는 $x=a$에서 **증가상태**에 있고, 반대일 경우 **감소상태**에 있다.
#
# 함수 $f(x)$가 미분가능할 때 $f'(a)>0$이면 $f(x)$는 $x-a$에서 **증가상태**에 있고, $f'(a)<0$ 경우 **감소상태**에 있다. $x=0$인 구간은 **증가상태도 감소상태도 아니다.**

# %% [markdown]
# ##### 2-2. 함수 증가·감소 예
# 함수 $f(x)=x^2$ 에 대하여 $f'(x)=2x$이다. 이때, $f'(1)=2$이므로 $x=1$에서 증가상태이고, $f'(-2)=-4$이므로 $x=-2$에서 감소상태에 있다. 그러나 $x=0$인 구간에서는 증가·감소 상태 둘다 아니다.

# %%
x = np.arange(-5,5,0.01)
plt.plot(x, 2*x, label="$f(x)=x^2$")
plt.plot(1,2,"o")
plt.plot(-2,-4,"o")
plt.annotate("$1,f'(1)$", xy=(0.5,3), fontsize=20)
plt.annotate("$-2,f'(-2)$", xy=(-2,-5), fontsize=20)
plt.xlim(-3,3);plt.ylim(-7,5);plt.grid();plt.legend(loc="lower right");plt.show();

# %% [markdown]
# ###### 3. 미분가능한 함수의 증가와 감소
#
# 함수 $y=f(x)$가 어떤 구간에서 미분가능할 때
# - $f'(x)>0$이면 함수 $f(x)$는 **그 구간에서 증가하고, 반대일 경우 감소한다.**
# - 함수 $f(x)$가 증가하면 그 구간에서 $f'(x)≥0$이고 감소하면 그 구간에서 $f'(x)≤0$이다.

# %% [markdown]
# ##### 3-2. 미분가능한 함수의 예
#
# - 함수 $f(x)=x^2$에 대하여 $f'(x)=2x$이다. $f'(x)>0$이므로 구간 (0,∞)에서 증가하고, $f'(x)<0$이면 $x<0$이므로 구간 (-∞,0)에서 감소한다.
# - 함수 $f(x)=x^3$은 $x_1<x_2$인 임의의 실수 $x_1, x_2$에 대하여 $f(x_1)<f(x_2)$ 이므로 구간 (-∞,-∞)에서 증가한다. 이때 $f'(x)=3x^2≥0$이다.

# %% [markdown]
# ----

# %% [markdown]
# ### 04_3. 함수의 극대 극소

# %% [markdown]
# ##### 1. 함수의 극대와 극소
#
# 함수 $f(x)$가 $x=a$에서 연속이고, x의 값이 증가하면서 x=a의 좌우에서
# 1. $f(x)$가 **증가상태에서 감소상태로 변하면** 함수 $f(x)$는 **$x=a$에서 극대라고 하며, $f(a)$를 극댓값이라고 한다. 반대의 경우를 극대라고 하며 그 때의 $f(a)$를 극솟값이라고 한다.**
# 1. **극댓값과 극솟값을 통틀어 극값이라고 한다.**

# %% [markdown]
# ##### 1-2. 극대, 극소 예
#
# 함수 $f(x)=-x^2+2x$에서 $x<1$이면 $f'(x)>0$, $x>1$이면 $f'(x)<0$이므로 $x$의 값이 증가하면서 $x=1$의 좌우에서 **증가상태에서 감소상태로 변한다.** 따라서 함수 $f(x)$는 $x=1$에서 극대이고 극댓값은 $f(1)=1$이다.

# %% [markdown]
# #### 2. 극값의 판정
#
# 함수 $f(x)$가 $x=a$에서 미분가능하고, **$x=a$에서 극값을 가지면 $f'(a)=0$이다.**
# - 일반적으로 **역은 성립하지 않는다.** 미분가능한 함수 $f(x)$에 대하여 $f'(x)=0$일때, $x=a$에서 극값을 갖지 않을 수도 있다.
# - 예를 들어 함수 $f(x)=x^3$은 $f'(0)=0$이지만, $x=0$의 좌우에서 $f(x)$의 증가 감소 상태가 변하지 않으므로 $x=0$에서 극값을 갖지 않는다.
# - 함수 $f(x)$가 $x=a$에서 극값을 가질 때, 미분계수 $f'(a)$가 존재하지 않을 수도 있다.
# - 예를 들어 함수 $f(x)=|x|$는 $x=0$에서 극소이지만 $f'(0)$은 존재하지 않는다.

# %% [markdown]
# #### 3. 미분가능한 함수의 극대와 극소 판정
#
# 미분가능한 함수 $f(x)$에서 $f'(a)=0$이고 $x=a$의 좌우에서 $f'(x)$의 부모가 **양에서 음으로 바뀌면 $f(x)$는 $x=a$에서 극대이다.** 반대일 경우 극소이다.

# %% [markdown]
# -----
