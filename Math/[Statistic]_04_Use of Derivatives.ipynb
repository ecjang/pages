# %% [markdown]
# ##### 미적분과 통계기본

# %% [markdown]
# # 04. 도함수의 활용

# %% [markdown]
# ----

# %% [markdown]
# ### 04_1. 접선의 방정식

# %% [markdown]
# ##### 곡선 위의 점에서의 접선의 방정식
#
# 함수 $f(x)$가 미분가능할 때, 곡선 $y=f(x)$ 위의 점 $P(a, f(a))$에서의 접선의 기울기는 $x=a$에서의 미분계수 $f'(a)$와 같다.
# - **점 $P(a,f(a))$에서의 접선의 방정식 : $y-f(a)=f'(a)(x-a)$** <br><br>
# - **점 $P(a,f(a))$과 수직인 방정식 : $y-f(a)=-\frac{1}{f'(a)}(x-a) \text{ (단, f'(a)≠0)} $**
#
# #####  예 : 곡선 $y=x^3+x^2$ 위의 점 $P(1,2)$ 에서의 접선의 방정식
# $y'=3x^2+2x$이므로 기울기는 $y'_{x=1}=3+2=5$이므로 접선의 방정식은 아래와 같다.
# - 접선의 방정식: $ y-2=5(x-1) \,=\, y=5x-3 $

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['axes.unicode_minus'] = False

# %%
x = np.arange(-2,3, 0.01)
plt.plot(x,x**3 + x**2, label="$f(x)$")
plt.plot(x, 5*x-3, label="접선")
plt.plot(1,2,'o')
plt.grid()
plt.legend()
plt.annotate('P',xy=(1,2), xytext=(1.1,5), fontsize=20 )
plt.show()

# %%
import matplotlib.font_manager as fm

# %%
fontprop = fm.FontProperties(fname="malgun.ttf", size=24)

import numpy as np
data = np.random.randint(-100, 100, 50).cumsum()
data

plt.plot(range(50), data, 'r')
plt.title('가격변동 추이')
plt.ylabel('가격')
# Out:
# Text(0,0.5,'가격')

# %%
https://financedata.github.io/posts/matplotlib-hangul-for-windows-anaconda.html
# Out:
#   File "<ipython-input-70-ca855e8f47a0>", line 1
#     https://financedata.github.io/posts/matplotlib-hangul-for-windows-anaconda.html
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# -----
